# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 17.2 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
# !pip install requests --upgrade --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install --upgrade pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf #Instalando e importando a API no código
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA

# %%
import requests
url = "https://investnews.com.br/financas/veja-a-lista-completa-dos-bdrs-disponiveis-para-pessoas-fisicas-na-b3/"
r = requests.get(url)
html = r.text
df_nomes_tickers = pd.read_html(html, header=0)[0]
df_nomes_tickers.head(10)
# Out:
#                   EMPRESA  CÓDIGO                           SETOR  \
# 0                      3M  MMMC34         Indústria diversificada
# 1                AB INBEV  ABUD34                         Bebidas
# 2                 ABB LTD  A1BB34                      Industrial
# 3                  ABBOTT  ABTT34                   Farmacêuticos
# 4                  ABBVIE  ABBV34  Medicamentos e Outros Produtos
# 5             ABIOMED INC  A1BM34                           Saúde
# 6              ACTIVISION  ATVI34                      Tecnologia
# 7               ADOBE INC  ADBE34                      Tecnologia
# 8  ADVANCE AUTO PARTS INC  A1AP34               Peças Automotivas
# 9            ADVANCED MIC  A1MD34                      Tecnologia
#
#   PAÍS DE ORIGEM
# 0            EUA
# 1        Bélgica
# 2    Switzerland
# 3            EUA
# 4            EUA
# 5            EUA
# 6            EUA
# 7            EUA
# 8            EUA
# 9            EUA

# %%
import pandas as pd
import matplotlib.pylab as plt
import yfinance as yf
import warnings
import matplotlib
import statsmodels.api as sm

# %%
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'G'

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados_series1 = yf.download("VALE3.SA", start="2018-01-01", end="2022-01-01")
dados_series2 = yf.download("PETR4.SA", start="2018-01-01", end="2022-01-01")
dados_series3 = yf.download("ITUB4.SA", start="2018-01-01", end="2022-01-01")
dados_series4 = yf.download("ABEV3.SA", start="2018-01-01", end="2022-01-01")
dados_series5 = yf.download("BBDC4.SA", start="2018-01-01", end="2022-01-01")
dados_series6 = yf.download("SANB11.SA", start="2018-01-01", end="2022-01-01")
dados_series7 = yf.download("BBAS3.SA", start="2018-01-01", end="2022-01-01")
dados_series8 = yf.download("JBSS3.SA", start="2018-01-01", end="2022-01-01")
dados_series9 = yf.download("KLBN11.SA", start="2018-01-01", end="2022-01-01")
dados_series10 = yf.download("WEGE3.SA", start="2018-01-01", end="2022-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
with pd.option_context('display.max_rows',10):
  print(dados_series1)
with pd.option_context('display.max_rows',10):
  print(dados_series2)
with pd.option_context('display.max_rows',10):
  print(dados_series3)
with pd.option_context('display.max_rows',10):
  print(dados_series4)
with pd.option_context('display.max_rows',10):
  print(dados_series5)
with pd.option_context('display.max_rows',10):
  print(dados_series6)
with pd.option_context('display.max_rows',10):
  print(dados_series7)
with pd.option_context('display.max_rows',10):
  print(dados_series8)
with pd.option_context('display.max_rows',10):
  print(dados_series9)
with pd.option_context('display.max_rows',10):
  print(dados_series10)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-01-02  40.439999  41.740002  40.439999  41.720001  29.179218  14156500
# 2018-01-03  41.830002  41.880001  41.299999  41.470001  29.004370  12744200
# 2018-01-04  41.810001  42.369999  41.520000  41.639999  29.123268  18433000
# 2018-01-05  41.570000  42.290001  41.310001  42.290001  29.577887  15251300
# 2018-01-08  42.400002  43.230000  42.400002  43.230000  30.235327  14542800
# ...               ...        ...        ...        ...        ...       ...
# 2021-12-23  79.949997  80.059998  78.800003  79.150002  72.463852  13121200
# 2021-12-27  78.870003  79.449997  78.260002  78.949997  72.280739  11371400
# 2021-12-28  78.510002  78.529999  76.570000  77.050003  70.541245  18923700
# 2021-12-29  76.379997  77.980003  76.349998  77.250000  70.724350  12113500
# 2021-12-30  77.989998  78.980003  77.610001  77.959999  71.374374  26568500
#
# [989 rows x 6 columns]
# ...

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series1['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series2['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series3['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series4['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series5['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series6['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series7['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series8['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series9['Close'].dropna())

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.distplot(dados_series10['Close'].dropna())
